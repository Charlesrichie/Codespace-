# %%
# Load libraries
from sklearn import preprocessing
import numpy as np
import io
import csv

# %%
# import csv file to google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7026c03e-31bf-4e29-ba8f-3b09818de39f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7026c03e-31bf-4e29-ba8f-3b09818de39f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bank-additional-full.csv to bank-additional-full (1).csv

# %%
bank_fulls = read_csv('bank-additional-full')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-efa8eb420ad9> in <module>()
# ----> 1 bank_fulls = read_csv('bank-additional-full')
#
# NameError: name 'read_csv' is not defined

# %%
(train_data, train_targets), (test_data, test_targets) =  bank-additional-full (1).csv.load_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-44a2be4b7148> in <module>()
# ----> 1 (train_data, train_targets), (test_data, test_targets) =  bank-additional-full (1).csv.load_data()
#
# NameError: name 'bank' is not defined

# %%
# Create scaler
scaler = preprocessing.StandardScaler()

# %%
# Transform the feature
features_standardized = scaler.fit_transform(features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-aa4afa05b2f8> in <module>()
#       1 # Transform the feature
# ----> 2 features_standardized = scaler.fit_transform(features)
#
# NameError: name 'features' is not defined
